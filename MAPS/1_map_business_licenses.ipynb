# %% [markdown]
# # Map business license data

# %% [markdown]
# #### Set up environment

# %%
# Install folium
# !pip install folium

# Import necessary packages 
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# Requirement already satisfied: folium in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: jinja2 in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: branca in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from folium) (0.3.0)
# Requirement already satisfied: six in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from folium) (1.11.0)
# Requirement already satisfied: requests in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from folium) (2.18.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from jinja2->folium) (1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from requests->folium) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from requests->folium) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davidplewis/anaconda3/lib/python3.6/site-packages (from requests->folium) (2018.4.16)
# distributed 1.21.8 requires msgpack, which is not installed.

# %% [markdown]
# #### Import and clean data

# %%
# Import business license data
import os.path
root_path = os.path.dirname(os.getcwd())
business_licenses  = pd.read_csv(os.path.join(root_path,"DATA/business_licenses.csv"))
# Out:
# /Users/davidplewis/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,6,23,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
business_licenses = business_licenses.dropna()
# business_licenses.shape returns rows and columns
number_of_licenses = len(business_licenses)

# %% [markdown]
# #### Map licenses

# %%
# Use folium to visualize map
m = folium.Map([41.8600, -87.6298], zoom_start=10)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# mark each license as a point

# for index, row in business_licenses.iterrows():
#     folium.CircleMarker([row['latitude'], row['longitude']],
#                         radius=15,
#                         popup=row['legal_name'],
#                         fill_color="grey", # divvy color
#                        ).add_to(m)

business_licenses.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]], 
                                              radius=.5, fill_color="grey")
                                             .add_to(m), axis=1)
# Out:
# 507842    <folium.features.CircleMarker object at 0x1a2f...
# 508168    <folium.features.CircleMarker object at 0x1a2f...
# 509776    <folium.features.CircleMarker object at 0x1a2f...
# 509815    <folium.features.CircleMarker object at 0x1a2f...
# 509871    <folium.features.CircleMarker object at 0x1a2f...
# 510907    <folium.features.CircleMarker object at 0x1a2f...
# 510970    <folium.features.CircleMarker object at 0x1a2f...
# 511222    <folium.features.CircleMarker object at 0x1a2f...
# 511696    <folium.features.CircleMarker object at 0x1a2f...
# 512417    <folium.features.CircleMarker object at 0x1a2f...
# 513913    <folium.features.CircleMarker object at 0x1a2f...
# 514811    <folium.features.CircleMarker object at 0x1a2f...
# 515322    <folium.features.CircleMarker object at 0x1a2f...
# 515377    <folium.features.CircleMarker object at 0x1a2f...
# 515519    <folium.features.CircleMarker object at 0x1a2d...
# 515847    <folium.features.CircleMarker object at 0x1a2d...
# 516332    <folium.features.CircleMarker object at 0x1a2d...
# 516846    <folium.features.CircleMarker object at 0x1a2d...
# 518409    <folium.features.CircleMarker object at 0x1a2d...
# 520316    <folium.features.CircleMarker object at 0x1a2d...
# 520606    <folium.features.CircleMarker object at 0x1a2f...
# 520771    <folium.features.CircleMarker object at 0x1a2f...
# 521178    <folium.features.CircleMarker object at 0x1a2f...
# 522097    <folium.features.CircleMarker object at 0x1a2f...
# 522437    <folium.features.CircleMarker object at 0x1a2d...
# 522476    <folium.features.CircleMarker object at 0x1a2d...
# 522554    <folium.features.CircleMarker object at 0x1a2d...
# 522812    <folium.features.CircleMarker object at 0x1a2d...
# 522986    <folium.features.CircleMarker object at 0x1a2d...
# 523953    <folium.features.CircleMarker object at 0x1a2d...
#                                 ...
# 933151    <folium.features.CircleMarker object at 0x1a2c...
# 933263    <folium.features.CircleMarker object at 0x1a2c...
# 933264    <folium.features.CircleMarker object at 0x1a34...
# 933566    <folium.features.CircleMarker object at 0x1a34...
# 933888    <folium.features.CircleMarker object at 0x1a34...
# 933909    <folium.features.CircleMarker object at 0x1a34...
# 933970    <folium.features.CircleMarker object at 0x1a34...
# 933977    <folium.features.CircleMarker object at 0x1a34...
# 934064    <folium.features.CircleMarker object at 0x1a34...
# 934547    <folium.features.CircleMarker object at 0x1a34...
# 934581    <folium.features.CircleMarker object at 0x1a34...
# 934782    <folium.features.CircleMarker object at 0x1a2c...
# 934818    <folium.features.CircleMarker object at 0x1a31...
# 934923    <folium.features.CircleMarker object at 0x1a2f...
# 935088    <folium.features.CircleMarker object at 0x1a34...
# 935247    <folium.features.CircleMarker object at 0x1a34...
# 935351    <folium.features.CircleMarker object at 0x1a34...
# 935842    <folium.features.CircleMarker object at 0x1a34...
# 936122    <folium.features.CircleMarker object at 0x1a2c...
# 936326    <folium.features.CircleMarker object at 0x1a34...
# 936556    <folium.features.CircleMarker object at 0x1a34...
# 936665    <folium.features.CircleMarker object at 0x1a34...
# 936701    <folium.features.CircleMarker object at 0x1a34...
# 936728    <folium.features.CircleMarker object at 0x1a2c...
# 936748    <folium.features.CircleMarker object at 0x1a2f...
# 937078    <folium.features.CircleMarker object at 0x1a2c...
# 937248    <folium.features.CircleMarker object at 0x1a34...
# 937318    <folium.features.CircleMarker object at 0x1a34...
# 937688    <folium.features.CircleMarker object at 0x1a34...
# 937729    <folium.features.CircleMarker object at 0x1a34...
# Length: 917, dtype: object

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
business_licenses[['latitude', 'longitude']].values
# Out:
# array([[ 41.90332173, -87.67598197],
#        [ 41.97359627, -87.65508289],
#        [ 41.94005906, -87.6639765 ],
#        ...,
#        [ 41.91745063, -87.68918063],
#        [ 41.75825583, -87.68292391],
#        [ 41.77913417, -87.69963358]])

# %%
# convert to (n, 2) nd-array format for heatmap
licenseArr = business_licenses[['latitude', 'longitude']].values
# licenseArr = list(map(tuple, licenseArr))

# plot heatmap
m.add_child(plugins.HeatMap(licenseArr.tolist(), radius=17))
# plugins.HeatMap(licenseArr).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
business_licenses["legal_name"]
